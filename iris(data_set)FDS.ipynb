# %% [markdown]
# <a href="https://colab.research.google.com/github/siddhuBikkina/titanic.2024008083/blob/main/iris(data_set)FDS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("iris.csv")

# %%
num_df = df.select_dtypes(include=['number'])

# %%
dispersion = pd.DataFrame({
      "Range": num_df.max() - num_df.min(),
          "Variance": num_df.var(),
              "Standard Deviation": num_df.std(),
                  "Interquartile Range (IQR)": num_df.quantile(0.75) - num_df.quantile(0.25),
                      "Coefficient of Variation (%)": (num_df.std() / num_df.mean()) * 100
})

# %%
print(dispersion)
# Out:
#               Range  Variance  Standard Deviation  Interquartile Range (IQR)  \
# sepal_length    3.6  0.685694            0.828066                        1.3
# sepal_width     2.4  0.188004            0.433594                        0.5
# petal_length    5.9  3.113179            1.764420                        3.5
# petal_width     2.4  0.582414            0.763161                        1.5
#
#               Coefficient of Variation (%)
# sepal_length                     14.171126
# sepal_width                      14.197587
# petal_length                     46.942721
# petal_width                      63.667470

# %%
df['Row_Range'] = num_df.max(axis=1) - num_df.min(axis=1)
df['Row_Variance'] = num_df.var(axis=1)
df['Row_Std_Deviation'] = num_df.std(axis=1)

print(df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  Row_Range  \
# 0           5.1          3.5           1.4          0.2  setosa        4.9
# 1           4.9          3.0           1.4          0.2  setosa        4.7
# 2           4.7          3.2           1.3          0.2  setosa        4.5
# 3           4.6          3.1           1.5          0.2  setosa        4.4
# 4           5.0          3.6           1.4          0.2  setosa        4.8
#
#    Row_Variance  Row_Std_Deviation
# 0      4.750000           2.179449
# 1      4.149167           2.036950
# 2      3.990000           1.997498
# 3      3.656667           1.912241
# 4      4.650000           2.156386

# %%
dispersion.to_excel("iris_dispersion.xlsx", index=False)

# %%
print("iris_dispersion.xlsx")
# Out:
# iris_dispersion.xlsx

# %%
print(df.columns)
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species',
#        'Row_Range', 'Row_Variance', 'Row_Std_Deviation'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# sepal_length         float64
# sepal_width          float64
# petal_length         float64
# petal_width          float64
# species               object
# Row_Range            float64
# Row_Variance         float64
# Row_Std_Deviation    float64
# dtype: object

# %%
print(df.shape)
# Out:
# (150, 8)

# %%
print(df.describe())
# Out:
#        sepal_length  sepal_width  petal_length  petal_width   Row_Range  \
# count    150.000000   150.000000    150.000000   150.000000  150.000000
# mean       5.843333     3.054000      3.758667     1.198667    4.644667
# std        0.828066     0.433594      1.764420     0.763161    0.484046
# min        4.300000     2.000000      1.000000     0.100000    3.200000
# 25%        5.100000     2.800000      1.600000     0.300000    4.325000
# 50%        5.800000     3.000000      4.350000     1.300000    4.600000
# 75%        6.400000     3.300000      5.100000     1.800000    4.900000
# max        7.900000     4.400000      6.900000     2.500000    5.900000
#
#        Row_Variance  Row_Std_Deviation
# count    150.000000         150.000000
# mean       4.385567           2.080765
# std        1.028475           0.237404
# min        2.386667           1.544884
# 25%        3.660000           1.913112
# 50%        4.278333           2.068413
# 75%        4.796875           2.190172
# ...

# %%
print(df.isnull().sum())
# Out:
# sepal_length         0
# sepal_width          0
# petal_length         0
# petal_width          0
# species              0
# Row_Range            0
# Row_Variance         0
# Row_Std_Deviation    0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
iris_numeric=df.select_dtypes(include=["float64","int64"])
corr_matrix=iris_numeric.corr()
print("correlation Matrix:")
print(corr_matrix)
# Out:
# correlation Matrix:
#                    sepal_length  sepal_width  petal_length  petal_width  \
# sepal_length           1.000000    -0.109369      0.871754     0.817954
# sepal_width           -0.109369     1.000000     -0.420516    -0.356544
# petal_length           0.871754    -0.420516      1.000000     0.962757
# petal_width            0.817954    -0.356544      0.962757     1.000000
# Row_Range              0.421109     0.375038     -0.026585    -0.177341
# Row_Variance           0.573234     0.330056      0.181452     0.052659
# Row_Std_Deviation      0.562270     0.349835      0.159319     0.031832
#
#                    Row_Range  Row_Variance  Row_Std_Deviation
# sepal_length        0.421109      0.573234           0.562270
# sepal_width         0.375038      0.330056           0.349835
# petal_length       -0.026585      0.181452           0.159319
# petal_width        -0.177341      0.052659           0.031832
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm',fmt=".2f")
plt.title("correlation Heatmapp")
plt.show()

# %%
print("Descriptive statistics:")
print(iris_numeric.describe())
print("/nVariance:")
print(iris_numeric.var())
print("\nstandard Deviation:")
print(iris_numeric.std())
# Out:
# Descriptive statistics:
#        sepal_length  sepal_width  petal_length  petal_width   Row_Range  \
# count    150.000000   150.000000    150.000000   150.000000  150.000000
# mean       5.843333     3.054000      3.758667     1.198667    4.644667
# std        0.828066     0.433594      1.764420     0.763161    0.484046
# min        4.300000     2.000000      1.000000     0.100000    3.200000
# 25%        5.100000     2.800000      1.600000     0.300000    4.325000
# 50%        5.800000     3.000000      4.350000     1.300000    4.600000
# 75%        6.400000     3.300000      5.100000     1.800000    4.900000
# max        7.900000     4.400000      6.900000     2.500000    5.900000
#
#        Row_Variance  Row_Std_Deviation
# count    150.000000         150.000000
# mean       4.385567           2.080765
# std        1.028475           0.237404
# min        2.386667           1.544884
# 25%        3.660000           1.913112
# 50%        4.278333           2.068413
# ...

# %%
cv=(iris_numeric.std()/iris_numeric.mean())
print("\ncoefficient of varition:")
print(cv)
# Out:
# coefficient of varition:
# sepal_length         0.141711
# sepal_width          0.141976
# petal_length         0.469427
# petal_width          0.636675
# Row_Range            0.104215
# Row_Variance         0.234514
# Row_Std_Deviation    0.114095
# dtype: float64

# %%
maximum=iris_numeric.max()
minimum=iris_numeric.min()
range=maximum-minimum
print("\ncoefficient of Range:")
print(range)
# Out:
# coefficient of Range:
# sepal_length         3.600000
# sepal_width          2.400000
# petal_length         5.900000
# petal_width          2.400000
# Row_Range            2.700000
# Row_Variance         5.575833
# Row_Std_Deviation    1.276906
# dtype: float64

# %%
Q1=iris_numeric.quantile(0.25)
Q3=iris_numeric.quantile(0.75)
coefficient_of_quartile_deviation=(Q3-Q1)/(Q3+Q1)
print("\ncofficient of Quartile Deviatiom:")
print(coefficient_of_quartile_deviation)
# Out:
# cofficient of Quartile Deviatiom:
# sepal_length         0.113043
# sepal_width          0.081967
# petal_length         0.522388
# petal_width          0.714286
# Row_Range            0.062331
# Row_Variance         0.134432
# Row_Std_Deviation    0.067521
# dtype: float64

# %%
mean=iris_numeric.mean()
mean_deviation=abs(iris_numeric-mean)
coefficient_of_mean_devition=mean_deviation.mean()/mean
print("\ncoefficient of mean Deviation:")
print(coefficient_of_mean_devition)
# Out:
# coefficient of mean Deviation:
# sepal_length         0.117665
# sepal_width          0.109068
# petal_length         0.415552
# petal_width          0.549722
# Row_Range            0.081640
# Row_Variance         0.175306
# Row_Std_Deviation    0.087022
# dtype: float64
